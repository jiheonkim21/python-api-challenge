# %% [markdown]
# # WeatherPy
# ----
#
# #### Data Analysis:
# - There is a strong negative correlation between latitude and max temp in northern hemisphere cities.
# - There is a negative correlation between latitude and max temp in southern hemisphere cities but the correlation is weaker than the one that exists between latitude and max temp in northern hemisphere cities.
# - There is no correlation between a city's latitude and its humidity.
# - There is no correlation between a city's latitude and its cloudiness.
# - There is no correlation between a city's latitude and its average wind speed.

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units=metric&q="
units = "imperial"

# set up lists to hold reponse info
city_name=[]
country_name = []
lat = []
lng = []
temp = []
date = []
humidity = []
max_temp = []
wind_speed = []
cloudiness = []
###DELETE ME###### for index, value in enumerate(test_list): 
# Loop through the list of cities and perform a request for data on each
for index, city in enumerate(cities):
    try:
        query_url = f"{url}appid={weather_api_key}&units={units}&q="
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        country_name.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
        print(f'{index+1}: {city} found.  Getting Data.')

    except (KeyError, IndexError, ValueError):
        print(f'{index}: {city} Not found. Skipping...')
print('Finished Reading Data')
# Out:
# 1: port elizabeth found.  Getting Data.
# 2: ulaangom found.  Getting Data.
# 3: udachnyy found.  Getting Data.
# 4: lebu found.  Getting Data.
# 5: kodiak found.  Getting Data.
# 6: lavrentiya found.  Getting Data.
# 6: taolanaro Not found. Skipping...
# 8: butaritari found.  Getting Data.
# 8: belushya guba Not found. Skipping...
# 10: rikitea found.  Getting Data.
# 11: margate found.  Getting Data.
# 12: dingle found.  Getting Data.
# 13: port alfred found.  Getting Data.
# 14: rutland found.  Getting Data.
# 15: lisakovsk found.  Getting Data.
# 16: mataura found.  Getting Data.
# 17: vestmanna found.  Getting Data.
# 17: haibowan Not found. Skipping...
# 19: zhangjiakou found.  Getting Data.
# 20: busselton found.  Getting Data.
# 21: castro found.  Getting Data.
# 22: rio gallegos found.  Getting Data.
# 23: namibe found.  Getting Data.
# 24: diego de almagro found.  Getting Data.
# 25: ushuaia found.  Getting Data.
# 26: hithadhoo found.  Getting Data.
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a new dictionary to contain information for each city in the list

cities_dict = {"City": city_name,
               "Country": country_name,
                "Lat": lat,
                "Lng": lng,
                "Temp": temp,
                "Date": date,
                "Humidity": humidity,
                "Max Temp": max_temp,
                "Wind Speed": wind_speed,
                "Cloudiness": cloudiness
               }

# Create a new dataFrame using the above created dictionary

cities_data = pd.DataFrame(cities_dict)

# Output the dataFrame as a .csv file

cities_data.to_csv(output_data_file, index=False)

# %%
cities_data.head()
# Out:
#                 City Country    Lat     Lng   Temp        Date  Humidity  \
# 0     Port Elizabeth      ZA -33.92   25.57  64.40  1587245863        93
# 1           Ulaangom      MN  49.98   92.07  33.35  1587246248        50
# 2            Udachny      RU  66.42  112.40   8.60  1587246248        50
# 3               Lebu      CL -37.62  -73.65  61.65  1587246056        72
# 4  Saint Paul Harbor      US  57.79 -152.41  46.40  1587246057        75
#
#    Max Temp  Wind Speed  Cloudiness
# 0     64.40        2.24           0
# 1     33.35        1.81           0
# 2      8.60        4.47           0
# 3     61.65        5.70          34
# 4     46.40       12.75           1

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create and display scatter plot of Latitude versus Max Temperature

cities_data.plot(x='Lat', y='Max Temp', kind='scatter')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs. Max Temperature")
plt.grid(True)
plt.savefig('../output_data/lat_vs_temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create and display scatter plot of Latitude versus Humidity

cities_data.plot(x='Lat', y='Humidity', kind='scatter')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")
plt.grid(True)
plt.savefig('../output_data/lat_vs_humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create and display scatter plot of Latitude versus Cloudiness

cities_data.plot(x='Lat', y='Cloudiness', kind='scatter')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid(True)
plt.savefig('../output_data/lat_vs_cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create and display scatter plot of Latitude versus Wind Speed

cities_data.plot(x='Lat', y='Wind Speed', kind='scatter')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed")
plt.grid(True)
plt.savefig('../output_data/lat_vs_windspeed.png')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_cities = cities_data.loc[cities_data['Lat']>0,:]
southern_cities = cities_data.loc[cities_data['Lat']<0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Max Temp of Northern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = northern_cities['Lat']
y_values = northern_cities['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

northern_cities.plot(x='Lat', y='Max Temp', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Northern Hemisphere City Latitude vs. Max Temp")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/northerncitytemps.png')
# Out:
# The r-squared is: 0.791755

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Max Temp of Southern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = southern_cities['Lat']
y_values = southern_cities['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

southern_cities.plot(x='Lat', y='Max Temp', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Southern Hemisphere City Latitude vs. Max Temp")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-50,50),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/southerncitytemps.png')
# Out:
# The r-squared is: 0.431569

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Humidity of Northern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = northern_cities['Lat']
y_values = northern_cities['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

northern_cities.plot(x='Lat', y='Humidity', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere City Latitude vs. Humidity")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(10,45),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/northerncityhumidity.png')
# Out:
# The r-squared is: 0.069967

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Humidity of Southern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = southern_cities['Lat']
y_values = southern_cities['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

southern_cities.plot(x='Lat', y='Humidity', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere City Latitude vs. Humidity")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-40,50),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/southerncityhumidity.png')
# Out:
# The r-squared is: 0.035615

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Cloudiness of Northern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = northern_cities['Lat']
y_values = northern_cities['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

northern_cities.plot(x='Lat', y='Cloudiness', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere City Latitude vs. Cloudiness")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/northerncitycloudiness.png')
# Out:
# The r-squared is: 0.020837

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Cloudiness of Southern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = southern_cities['Lat']
y_values = southern_cities['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

southern_cities.plot(x='Lat', y='Cloudiness', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere City Latitude vs. Cloudiness")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/southerncitycloudiness.png')
# Out:
# The r-squared is: 0.012777

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Wind Speed of Northern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = northern_cities['Lat']
y_values = northern_cities['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

northern_cities.plot(x='Lat', y='Wind Speed', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere City Latitude vs. Wind Speed")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/northerncitywindspeed.png')
# Out:
# The r-squared is: 0.001998

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create and display scatter plot of Latitude versus Wind Speed of Southern Hemisphere cities
# Perform linear regression between the two and overlay the linear regression line and formula

x_values = southern_cities['Lat']
y_values = southern_cities['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

print(f"The r-squared is: {round(rvalue**2,6)}")

southern_cities.plot(x='Lat', y='Wind Speed', kind='scatter')

plt.plot(x_values,regress_values,"r-")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere City Latitude vs. Wind Speed")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_eq,(-30,10),fontsize=15,color="red")
plt.grid(True)
plt.savefig('../output_data/northerncitywindspeed.png')
# Out:
# The r-squared is: 0.106791
